# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')
# %load_ext rpy2.ipython

# %R require(ggplot2)
# %R require(data.table)
# Out:
# array([1], dtype=int32)

# %%
# Make a pandas DataFrame
df = pd.DataFrame({'Alphabet': ['a', 'b', 'c', 'd','e', 'f', 'g', 'h','i'],
                   'A': [4, 3, 5, 2, 1, 7, 7, 5, 9],
                   'B': [0, 4, 3, 6, 7, 10,11, 9, 13],
                   'C': [1, 2, 3, 1, 2, 3, 1, 2, 3]})
# Take the name of input variable df and assign it to an R variable of the same name
# %R -i df

# %%
# %%R -o df
# df <- data.table(df)
# df[, D := A +B]
# print(df)
# ggplot(data=df) + geom_point(aes(x=A, y=B, color=C))
# Out:
#    A Alphabet  B C  D
# 1: 4        a  0 1  4
# 2: 3        b  4 2  7
# 3: 5        c  3 3  8
# 4: 2        d  6 1  8
# 5: 1        e  7 2  8
# 6: 7        f 10 3 17
# 7: 7        g 11 1 18
# 8: 5        h  9 2 14
# 9: 9        i 13 3 22

# %%
pd.DataFrame(np.array(df))
# Out:
#    0  1  2  3  4   5   6   7   8
# 0  4  3  5  2  1   7   7   5   9
# 1  a  b  c  d  e   f   g   h   i
# 2  0  4  3  6  7  10  11   9  13
# 3  1  2  3  1  2   3   1   2   3
# 4  4  7  8  8  8  17  18  14  22

# %%
df
# Out:
# R object with classes: ('data.table', 'data.frame') mapped to:
# <DataFrame - Python:0x7fde4f30f7c8 / R:0x4dcd1f0>
# [IntVector, StrVector, IntVector, IntVector, IntVector]
#   A: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x7fde53444a48 / R:0x4dc83a0>
# [4, 3, 5, 2, ..., 7, 7, 5, 9]
#   Alphabet: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x7fdd94db40c8 / R:0x3e25670>
# ['a', 'b', 'c', 'd', ..., 'f', 'g', 'h', 'i']
#   B: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x7fdd94db4488 / R:0x4dc8338>
# [0, 4, 3, 6, ..., 10, 11, 9, 13]
#   C: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x7fdd94db4c88 / R:0x4dc82d0>
# [1, 2, 3, 1, ..., 3, 1, 2, 3]
#   D: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x7fdd94d45108 / R:0x4f44d28>
# [4, 7, 8, 8, ..., 17, 18, 14, 22]
